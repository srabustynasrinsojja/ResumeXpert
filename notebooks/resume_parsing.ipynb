# %%
import sys
from pathlib import Path
sys.path.append(str(Path("..").resolve()))

# %%
from utils.gemini_resume_parser import parse_resume_file, save_parsed_resume_json

# %%
sample_path = "../data/test_resumes/cvv.docx"
parsed = parse_resume_file(sample_path)
parsed.model_dump()
# Out:
# {'candidate_name': 'MD. SHAHIDUL ISLAM',
#  'headline': 'Python Backend Developer',
#  'email': 'shahidul.islam@email.com',
#  'phone': '+880 17XX-XXXXXX',
#  'location': 'Dhaka, Bangladesh',
#  'linkedin': 'linkedin.com/in/shahidul',
#  'github': 'github.com/shahidul-dev',
#  'portfolio': None,
#  'summary': 'Results-driven Python Backend Developer with 4+ years of experience in designing and maintaining scalable backend systems. Proficient in building high-performance REST APIs, optimizing database queries, and deploying microservices on AWS. Adept at collaborating with cross-functional teams to deliver robust cloud-native solutions.',
#  'total_experience_years': 4.0,
#  'skills': {'technical': ['python',
#    'sql',
#    'bash',
#    'fastapi',
#    'django',
#    'flask',
#    'postgresql',
#    'mysql',
#    'mongodb',
#    'rest api',
#    'microservices',
#    'event-driven systems',
#    'sqlalchemy',
#    'jwt',
#    'oauth2',
#    'celery',
#    'redis'],
# ...

# %%
save_parsed_resume_json(parsed, "../data/parsed_resumes/cvv.json")
print("saved")
# Out:
# saved
